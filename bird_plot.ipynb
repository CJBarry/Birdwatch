# %%
# create class for birds

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
# csv file format
# county, species, mean, rank, % gardens
# imported using pandas - good for large data

# %%
data=pd.read_csv('West_Yorkshire_Birds_2015.csv',sep=',')

# %%
#print(data.species)

# %%
#class Birds(object):
    #def __init__(self,bird_name,mean):

# %%
print(data.columns)
# Out:
# Index(['county', 'species', 'mean_birds', 'rank_birds', 'Percent_gardens'], dtype='object')

# %%
my_xticks = [data.species]
plt.xticks(data.rank_birds, my_xticks)
# Out:
# ([<matplotlib.axis.XTick at 0x1181e1978>,
#   <matplotlib.axis.XTick at 0x1181c5a20>,
#   <matplotlib.axis.XTick at 0x1181ed748>,
#   <matplotlib.axis.XTick at 0x118d7e8d0>,
#   <matplotlib.axis.XTick at 0x118d83320>,
#   <matplotlib.axis.XTick at 0x118d83d30>,
#   <matplotlib.axis.XTick at 0x118d87780>,
#   <matplotlib.axis.XTick at 0x118fb71d0>,
#   <matplotlib.axis.XTick at 0x118fb7be0>,
#   <matplotlib.axis.XTick at 0x118fbb630>,
#   <matplotlib.axis.XTick at 0x118fbe080>,
#   <matplotlib.axis.XTick at 0x118fbea90>,
#   <matplotlib.axis.XTick at 0x118fc34e0>,
#   <matplotlib.axis.XTick at 0x118fc3ef0>,
#   <matplotlib.axis.XTick at 0x118fc8940>,
#   <matplotlib.axis.XTick at 0x118fcb390>,
#   <matplotlib.axis.XTick at 0x118fcbda0>,
#   <matplotlib.axis.XTick at 0x118fcf7f0>,
#   <matplotlib.axis.XTick at 0x118fd3240>,
#   <matplotlib.axis.XTick at 0x118fd3c50>,
#   <matplotlib.axis.XTick at 0x118fd86a0>,
#   <matplotlib.axis.XTick at 0x118fdc0f0>,
#   <matplotlib.axis.XTick at 0x118fdcb00>,
#   <matplotlib.axis.XTick at 0x118fdf550>,
#   <matplotlib.axis.XTick at 0x118fdff60>,
#   <matplotlib.axis.XTick at 0x118fe39b0>,
#   <matplotlib.axis.XTick at 0x118fe7400>,
#   <matplotlib.axis.XTick at 0x118fe7e10>,
#   <matplotlib.axis.XTick at 0x118feb860>,
#   <matplotlib.axis.XTick at 0x118fef2b0>,
#   <matplotlib.axis.XTick at 0x118fefcc0>,
#   <matplotlib.axis.XTick at 0x118ff3710>,
#   <matplotlib.axis.XTick at 0x119100160>,
#   <matplotlib.axis.XTick at 0x119100b70>,
#   <matplotlib.axis.XTick at 0x1181f6d68>,
#   <matplotlib.axis.XTick at 0x1181ed358>,
#   <matplotlib.axis.XTick at 0x119100dd8>,
#   <matplotlib.axis.XTick at 0x119105780>,
#   <matplotlib.axis.XTick at 0x1191081d0>,
#   <matplotlib.axis.XTick at 0x119108be0>,
#   <matplotlib.axis.XTick at 0x11910d630>,
#   <matplotlib.axis.XTick at 0x119110080>,
#   <matplotlib.axis.XTick at 0x119110a90>,
#   <matplotlib.axis.XTick at 0x1191134e0>,
#   <matplotlib.axis.XTick at 0x119113ef0>,
#   <matplotlib.axis.XTick at 0x11911a940>,
#   <matplotlib.axis.XTick at 0x11911c390>,
#   <matplotlib.axis.XTick at 0x11911cda0>,
#   <matplotlib.axis.XTick at 0x1191207f0>,
#   <matplotlib.axis.XTick at 0x119124240>,
#   <matplotlib.axis.XTick at 0x119124c50>,
#   <matplotlib.axis.XTick at 0x1191276a0>,
#   <matplotlib.axis.XTick at 0x11912d0f0>,
#   <matplotlib.axis.XTick at 0x11912db00>,
#   <matplotlib.axis.XTick at 0x119130550>,
#   <matplotlib.axis.XTick at 0x119130f60>,
#   <matplotlib.axis.XTick at 0x1191359b0>,
#   <matplotlib.axis.XTick at 0x119139400>,
#   <matplotlib.axis.XTick at 0x119139e10>,
#   <matplotlib.axis.XTick at 0x11913e860>,
#   <matplotlib.axis.XTick at 0x1191412b0>,
#   <matplotlib.axis.XTick at 0x119141cc0>,
#   <matplotlib.axis.XTick at 0x119145710>,
#   <matplotlib.axis.XTick at 0x119149160>,
#   <matplotlib.axis.XTick at 0x119149b70>,
#   <matplotlib.axis.XTick at 0x11914c5c0>,
#   <matplotlib.axis.XTick at 0x11914cfd0>,
#   <matplotlib.axis.XTick at 0x119152a20>,
#   <matplotlib.axis.XTick at 0x119155470>,
#   <matplotlib.axis.XTick at 0x119155e80>,
#   <matplotlib.axis.XTick at 0x1191598d0>,
#   <matplotlib.axis.XTick at 0x11915d320>,
#   <matplotlib.axis.XTick at 0x11915dd30>],
#  <a list of 1 Text xticklabel objects>)

# %%
% matplotlib inline
plt.plot(data.rank_birds,data.mean_birds)

# %%
selected_values=data.mean_birds > 1.00
labels=data.species[selected_values]
mean_birds=data.mean_birds[selected_values]

plt.pie(mean_birds,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x11ac42940>,
#   <matplotlib.patches.Wedge at 0x11ac485c0>,
#   <matplotlib.patches.Wedge at 0x11ac4e240>,
#   <matplotlib.patches.Wedge at 0x11ac4ee80>,
#   <matplotlib.patches.Wedge at 0x11ac54b00>,
#   <matplotlib.patches.Wedge at 0x11ac5a780>,
#   <matplotlib.patches.Wedge at 0x11ac5f400>,
#   <matplotlib.patches.Wedge at 0x11ac65080>,
#   <matplotlib.patches.Wedge at 0x11ac65cc0>,
#   <matplotlib.patches.Wedge at 0x11aca4940>],
#  [<matplotlib.text.Text at 0x11ac48160>,
#   <matplotlib.text.Text at 0x11ac48da0>,
#   <matplotlib.text.Text at 0x11ac4ea20>,
#   <matplotlib.text.Text at 0x11ac546a0>,
#   <matplotlib.text.Text at 0x11ac5a320>,
#   <matplotlib.text.Text at 0x11ac5af60>,
#   <matplotlib.text.Text at 0x11ac5fbe0>,
#   <matplotlib.text.Text at 0x11ac65860>,
#   <matplotlib.text.Text at 0x11aca44e0>,
#   <matplotlib.text.Text at 0x11acab160>])
